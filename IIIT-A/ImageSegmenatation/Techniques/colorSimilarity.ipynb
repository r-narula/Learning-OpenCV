# %%
import cv2
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib import colors
import numpy as np
from matplotlib.colors import hsv_to_rgb

# %%
img = cv2.imread("nemo.jpg")
nemo = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(nemo)

# %%
# HSV plot
hsv_nemo = cv2.cvtColor(nemo, cv2.COLOR_RGB2HSV)

# %%
plt.subplot(1,2,1)
plt.imshow(nemo)
plt.subplot(1,2,2)
plt.imshow(hsv_nemo)

# %%
light_orange = (1, 150, 200)
dark_orange = (80, 255, 255)

# %%
mask = cv2.inRange(hsv_nemo, light_orange, dark_orange)
result = cv2.bitwise_and(nemo, nemo, mask=mask) 
# This bitwise conjuction of the things in the 
plt.subplot(1, 3, 1)
plt.imshow(mask, cmap="gray")
plt.subplot(1, 3, 2)
plt.imshow(result)
plt.subplot(1,3,3)
plt.imshow(mask,"gray")
plt.show()

# %%
light_white = (0, 0, 200)
dark_white = (145, 60, 255)

# %%
mask_white = cv2.inRange(hsv_nemo, light_white, dark_white)
result_white = cv2.bitwise_and(nemo, nemo, mask=mask_white)
plt.subplot(1, 2, 1)
plt.imshow(mask_white, cmap="gray")
plt.subplot(1, 2, 2)
plt.imshow(result_white)
plt.show()

# %%
final_mask = mask + mask_white

final_result = cv2.bitwise_and(nemo, nemo, mask=final_mask)
plt.subplot(1, 3, 1)
plt.imshow(final_mask, cmap="gray")
plt.subplot(1, 3, 2)
plt.imshow(final_result)
plt.subplot(1,3,3)
plt.imshow(nemo)
plt.show()

# %% [markdown]
# ## What we learned from this ?
# we are making the image segmentation through colors only.. Like selecting a color range and then we are just outputting that range.

# %% [markdown]
# ```
# https://realpython.com/python-opencv-color-spaces/
# ```
# Link from where I have Done this work.
